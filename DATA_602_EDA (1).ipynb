# %% [markdown]
# ## CRIME INCIDENT REPORTS
#
# - Officers of the Boston Police Department (BPD) prepare crime incident reports to keep track of the early circumstances surrounding an occurrence. consisting of a smaller number of fields aimed for gathering information on an incident's specifics, such as when and where it took place.
#
# <b>Objective</b> - I want to be able to anticipate when crimes will take place based on the kind of offense committed and the time of day.

# %% [markdown]
# <b>Dataset Description</b>: Dataset had been extracted from the crime incident reports of Boston Police Department "Analyze Boston". This dataset contains the the crimes which are done and they are categorized by the type of offense they are involved in the year 2022

# %% [markdown]
# - Access to Dataset: https://data.boston.gov/dataset/crime-incident-reports-august-2015-to-date-source-new-system/resource/313e56df-6d77-49d2-9c49-ee411f10cf58

# %% [markdown]
# <b> Intially The dataset consists of 18941 observations & 17 Columns.
#
#
# - <b>INCIDENT_NUMBER</b>: Unique NUmber for the each offense recorded
#
#
# - <b>OFFENSE_CODE</b>: Each Type of Offense has unique code according to the type of Offense
#
#
# - <b>OFFENSE_CODE_GROUP</b>: In which group of category the offenses are categorized.
#
#
# - <b>OFFENSE_DESCRIPTION</b>: It involves types of offenses they are commited such as {Burgulary, theft, loss of property or an item}
#
#
# - <b>DISTRICT</b>: In which district this offenses were took place and each offense has a unique code.
#
#
# - <b>REPORTING_AREA</b>: For the better picture of the offense and to diffrentiate from the other areas there diffrent set of areas with a unique number to them.
#
#
# - <b>SHOOTING</b>: If that particular offense included Shooting or not
#
#
# - <b>OCCURRED_ON_DATE</b>: At which date the particular incident took place and this column gives us the time of the incident.
#
#
# - <b>YEAR</b>: In which year all this offense took place Here we are taking year wise data from the Boston Police department for this particular dataset I have taken year 2021 dataset.
#
#
# - <b>MONTH</b>:  In which month of the year the offenses wre took place.
#
#
# - <b>DAY_OF_WEEK</b>: On which days the offenses were took place.
#
#
# - <b>HOUR</b>: At what particular hour of the day the offense are recorded.
#
#
# - <b>UCR_PART</b>: They haven't mentioned anything particular or important related to the dataset with the UCR_PART.
#
#
# - <b>STREET</b>: Offenses are recorded in which street of that are area the offense took place.
#
#
# - <b>Lat</b>: Latitude of that particular location.
#
#
# - <b>Long</b>: Longitude of that particular location.
#
#
# - <b>Location</b>: Which consists of both longitude and latitude coordinates of the location.

# %% [markdown]
# <b>Libraries which are used are listed below:</b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# - <b>Importing the dataset</b>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/vishu3883/DATA_602/main/DATA/Boston_Crime_Data_2021.csv", low_memory=False)
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP       OFFENSE_DESCRIPTION  \
# 0       PLTEST005           520                 NaN    BURGLARY - RESIDENTIAL
# 1       PLTEST003          3114                 NaN      INVESTIGATE PROPERTY
# 2       PLTEST002          3114                 NaN      INVESTIGATE PROPERTY
# 3       PLTEST001          3114                 NaN      INVESTIGATE PROPERTY
# 4       312030979          3201                 NaN  PROPERTY - LOST/ MISSING
#
#   DISTRICT REPORTING_AREA  SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0       B2            289         1  2021-10-13 00:00:00  2021     10
# 1       B2            289         0  2021-05-12 00:00:00  2021      5
# 2       B2            289         0  2021-05-12 00:00:00  2021      5
# 3       B2                        0  2021-03-29 00:00:00  2021      3
# 4      E13            465         0  2021-03-22 00:00:00  2021      3
#
#   DAY_OF_WEEK  HOUR  UCR_PART           STREET        Lat       Long  \
# 0   Wednesday     0       NaN    SCHROEDER PLZ  42.333679 -71.091878
# 1   Wednesday     0       NaN    SCHROEDER PLZ  42.333679 -71.091878
# 2   Wednesday     0       NaN    SCHROEDER PLZ  42.333679 -71.091878
# 3      Monday     0       NaN  SCHROEDER PLAZA   0.000000   0.000000
# 4      Monday     0       NaN    BLUE HILL AVE  42.284826 -71.091374
#
#                                   Location
# 0  (42.33367921810846, -71.09187754618458)
# 1  (42.33367921810846, -71.09187754618458)
# 2  (42.33367921810846, -71.09187754618458)
# 3                                   (0, 0)
# 4  (42.28482576580488, -71.09137368938802)

# %%
print(f'Rows: {df.shape[0]:,}')
print(f'Columns: {df.shape[1]:,}')
# Out:
# Rows: 71,721
# Columns: 17

# %%
df.columns
# Out:
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'SHOOTING',
#        'OCCURRED_ON_DATE', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'HOUR', 'UCR_PART',
#        'STREET', 'Lat', 'Long', 'Location'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71721 entries, 0 to 71720
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   INCIDENT_NUMBER      71721 non-null  object
#  1   OFFENSE_CODE         71721 non-null  int64
#  2   OFFENSE_CODE_GROUP   0 non-null      float64
#  3   OFFENSE_DESCRIPTION  71721 non-null  object
#  4   DISTRICT             70728 non-null  object
#  5   REPORTING_AREA       71721 non-null  object
#  6   SHOOTING             71721 non-null  int64
#  7   OCCURRED_ON_DATE     71721 non-null  object
#  8   YEAR                 71721 non-null  int64
#  9   MONTH                71721 non-null  int64
#  10  DAY_OF_WEEK          71721 non-null  object
#  11  HOUR                 71721 non-null  int64
#  12  UCR_PART             0 non-null      float64
#  13  STREET               71042 non-null  object
#  14  Lat                  71721 non-null  float64
#  15  Long                 71721 non-null  float64
#  16  Location             71721 non-null  object
# dtypes: float64(4), int64(5), object(8)
# memory usage: 9.3+ MB

# %% [markdown]
# - <b>Finding the Null values in the each column of the dataset:</b>

# %%
df.isnull().sum().sort_values(ascending=False).plot(kind='barh')
plt.title('Nulls in each column')
plt.xlabel('Null Count')
plt.ylabel('Column',fontsize=12)
# Out:
# Text(0, 0.5, 'Column')

# %% [markdown]
# - This dataset is having some non significant columns which have no information in it and neither required for the future analysis part. So, we are removing those columns.
# - We removed OFFENSE_CODE_GROUP because the whole column consists of null values it will not be useful for the future analysis parts.
# - 'Lat', 'Long', 'Location' columns are not going to give any useful analysis according to the prediction which I needed.
# - UCR_PART this whole column consists of the null values.

# %%
df1 = df.drop(['OFFENSE_CODE_GROUP','Lat','Long','Location','UCR_PART'], axis = 1)
df1.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE       OFFENSE_DESCRIPTION DISTRICT  \
# 0       PLTEST005           520    BURGLARY - RESIDENTIAL       B2
# 1       PLTEST003          3114      INVESTIGATE PROPERTY       B2
# 2       PLTEST002          3114      INVESTIGATE PROPERTY       B2
# 3       PLTEST001          3114      INVESTIGATE PROPERTY       B2
# 4       312030979          3201  PROPERTY - LOST/ MISSING      E13
#
#   REPORTING_AREA  SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  \
# 0            289         1  2021-10-13 00:00:00  2021     10   Wednesday
# 1            289         0  2021-05-12 00:00:00  2021      5   Wednesday
# 2            289         0  2021-05-12 00:00:00  2021      5   Wednesday
# 3                        0  2021-03-29 00:00:00  2021      3      Monday
# 4            465         0  2021-03-22 00:00:00  2021      3      Monday
#
#    HOUR           STREET
# 0     0    SCHROEDER PLZ
# 1     0    SCHROEDER PLZ
# 2     0    SCHROEDER PLZ
# 3     0  SCHROEDER PLAZA
# 4     0    BLUE HILL AVE

# %% [markdown]
# - I'm spliting the OCCURRED_ON_DATE column into DATE & TIME

# %%
df1['Date']= df1["OCCURRED_ON_DATE"].apply(lambda x: x.split(" ")[0])
df1['Time']= df1["OCCURRED_ON_DATE"].apply(lambda x: x.split(" ")[1])
df1.drop(['OCCURRED_ON_DATE'], axis = 1, inplace = True)
df1.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE       OFFENSE_DESCRIPTION DISTRICT  \
# 0       PLTEST005           520    BURGLARY - RESIDENTIAL       B2
# 1       PLTEST003          3114      INVESTIGATE PROPERTY       B2
# 2       PLTEST002          3114      INVESTIGATE PROPERTY       B2
# 3       PLTEST001          3114      INVESTIGATE PROPERTY       B2
# 4       312030979          3201  PROPERTY - LOST/ MISSING      E13
#
#   REPORTING_AREA  SHOOTING  YEAR  MONTH DAY_OF_WEEK  HOUR           STREET  \
# 0            289         1  2021     10   Wednesday     0    SCHROEDER PLZ
# 1            289         0  2021      5   Wednesday     0    SCHROEDER PLZ
# 2            289         0  2021      5   Wednesday     0    SCHROEDER PLZ
# 3                        0  2021      3      Monday     0  SCHROEDER PLAZA
# 4            465         0  2021      3      Monday     0    BLUE HILL AVE
#
#          Date      Time
# 0  2021-10-13  00:00:00
# 1  2021-05-12  00:00:00
# 2  2021-05-12  00:00:00
# 3  2021-03-29  00:00:00
# 4  2021-03-22  00:00:00

# %% [markdown]
# ### Data Cleaning
# <b>Removing null values:</b>
# - Now checking for the null values in each columns for better results on the analysis.

# %%
df1.isnull().sum().sort_values(ascending=False)
# Out:
# DISTRICT               993
# STREET                 679
# INCIDENT_NUMBER          0
# OFFENSE_CODE             0
# OFFENSE_DESCRIPTION      0
# REPORTING_AREA           0
# SHOOTING                 0
# YEAR                     0
# MONTH                    0
# DAY_OF_WEEK              0
# HOUR                     0
# Date                     0
# Time                     0
# dtype: int64

# %% [markdown]
# - Intially there are 993 null values in the DISTRICT column & 679 null values in the street.

# %%
df1.dropna(inplace=True)
df1.isnull().sum().sort_values(ascending=False)
# Out:
# INCIDENT_NUMBER        0
# OFFENSE_CODE           0
# OFFENSE_DESCRIPTION    0
# DISTRICT               0
# REPORTING_AREA         0
# SHOOTING               0
# YEAR                   0
# MONTH                  0
# DAY_OF_WEEK            0
# HOUR                   0
# STREET                 0
# Date                   0
# Time                   0
# dtype: int64

# %% [markdown]
# - This is the final dataset with no null values in Rows and columns and ready for the future analysis.

# %%
df1.shape
# Out:
# (70089, 13)

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Now coming to the EDA part we are peforming distribution on the columns which are having some intresting characteristics shown up.

# %%
df1['OFFENSE_CODE'].value_counts().plot(kind='bar',title='Unique Code for Offense',figsize=(15,6))
plt.xticks(rotation='vertical')
plt.gcf().set_size_inches(20,10)
plt.show()

# %% [markdown]
# - Offense code shows some intresting bar graphs of the data where CODE:3115 is taken place more often rather compared with the other offenses.

# %%
df1['OFFENSE_DESCRIPTION'].value_counts().plot(kind='bar',title='Types of offenses',figsize=(15,6))
plt.xticks(rotation=90)
plt.gcf().set_size_inches(20,10)
plt.show()

# %% [markdown]
# - Earlier in the OFFENSE CODE distribution Graph we had seen a hike in one of the code and now with the help of OFFENSE DESCRIPTION graph we can name them and have a better understanding of the graph.
# - 'Investigate Personal' is shown the highest Offense ever recorded according to the data.

# %%
df1['DISTRICT'].value_counts().plot(kind='bar',title='Categorized by the District',figsize=(15,6))
plt.xticks(rotation=90)
plt.gcf().set_size_inches(20,10)
plt.show()

# %% [markdown]
# - Here we can get that which Districts have more number of offenses took place and 'B2' has the highest number when compared with other Districts

# %%
df1.columns
# Out:
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_DESCRIPTION', 'DISTRICT',
#        'REPORTING_AREA', 'SHOOTING', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'HOUR',
#        'STREET', 'Date', 'Time'],
#       dtype='object')

# %%
df1['SHOOTING'].value_counts().plot(kind='bar',title='Shooting happend at that time of offense',figsize=(10,6))
#plt.xticks(rotation=90)
plt.gcf().set_size_inches(20,10)
plt.show()

# %% [markdown]
# - Most of the offenses are recorded without shooting and only few are recorded with shooting and here '1' indicates Yes and '0' as No for the shooting.

# %%
df1.MONTH.value_counts(normalize=True)
#df1['MONTH'].value_counts().plot(kind='bar',title='Shooting happend at that time of offense',figsize=(10,6))
df1.MONTH.value_counts(normalize=True).plot.pie(radius= 2,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# - Here Months are taken according to the numbers and more number of offenses are were recorded in the months of '8, 10' and least number of Offenses are taken in the month of '2'.

# %%
df1.groupby('OFFENSE_DESCRIPTION')['HOUR'].mean()
# Out:
# OFFENSE_DESCRIPTION
# AFFRAY                                                            13.217391
# AIRCRAFT INCIDENTS                                                15.105263
# ANIMAL ABUSE                                                      11.588235
# ANIMAL INCIDENTS (DOG BITES, LOST DOG, ETC)                       13.803571
# ARSON                                                             14.217391
#                                                                     ...
# VERBAL DISPUTE                                                    13.433985
# VIOLATION - CITY ORDINANCE                                        12.385965
# WARRANT ARREST - BOSTON WARRANT (MUST BE SUPPLEMENTAL)            11.454545
# WARRANT ARREST - OUTSIDE OF BOSTON WARRANT                        11.528662
# WEAPON VIOLATION - CARRY/ POSSESSING/ SALE/ TRAFFICKING/ OTHER    12.244898
# Name: HOUR, Length: 121, dtype: float64

# %%
df1.groupby('OFFENSE_DESCRIPTION')['HOUR'].median()
# Out:
# OFFENSE_DESCRIPTION
# AFFRAY                                                            15.0
# AIRCRAFT INCIDENTS                                                17.0
# ANIMAL ABUSE                                                      13.0
# ANIMAL INCIDENTS (DOG BITES, LOST DOG, ETC)                       14.0
# ARSON                                                             18.0
#                                                                   ...
# VERBAL DISPUTE                                                    14.0
# VIOLATION - CITY ORDINANCE                                        13.0
# WARRANT ARREST - BOSTON WARRANT (MUST BE SUPPLEMENTAL)            11.0
# WARRANT ARREST - OUTSIDE OF BOSTON WARRANT                        11.0
# WEAPON VIOLATION - CARRY/ POSSESSING/ SALE/ TRAFFICKING/ OTHER    14.0
# Name: HOUR, Length: 121, dtype: float64

# %%
sns.boxplot(df1.OFFENSE_DESCRIPTION,df1.HOUR)
plt.gcf().set_size_inches(30,15)
plt.xticks(rotation='vertical',)
plt.show()

# %% [markdown]
# - As compared with the mean and median in the above analysis we get that Box plot shows some diffrent picture we are taking 'OFFENSE DESCRIPTION' & 'HOUR' as the two main features and contructing boxplot for them.
# - Analysis shows that the mostly the offenses are taking at 10 & 15 hours and only few offenses are taken place in irregular times.
